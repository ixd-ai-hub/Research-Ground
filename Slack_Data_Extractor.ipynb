# %% [markdown]
# <a href="https://colab.research.google.com/github/ixd-ai-hub/Research-Ground/blob/project%2FCU-865d7na0b-chat-emotion-analyzer/Slack_Data_Extractor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <font color='red'>*Channel ID and Timestamps used in the following demo, won't align with your experiments. Please update those accordingly.</font>

# %%
# install 3rd parties
# !pip install slack-sdk
# Out:
# Collecting slack-sdk
#   Downloading slack_sdk-3.22.0-py2.py3-none-any.whl (281 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 281.1/281.1 kB 6.1 MB/s eta 0:00:00
# Installing collected packages: slack-sdk
# Successfully installed slack-sdk-3.22.0

# %%
import os
from typing import List, Dict
import traceback
from slack_sdk import WebClient
from slack_sdk.errors import SlackApiError

# %%
class SlackDataExtractor:
    def __init__(self, bot_token: str) -> None:
        self.__client = WebClient(token=bot_token) # protect attribute

    def get_channels(self, name_only: bool=False) -> List[Dict]:
        """Get details of all the channels that ChatBot is in."""
        try:
            response = self.__client.conversations_list()
            channels = response["channels"]
            if name_only:
                channels = [{'id': d['id'], 'name': d['name']} for d in channels]

            return channels
        except SlackApiError as e:
            print(f"Error fetching conversations: {e.response['error']}")
            traceback.print_exc()

    def get_channel_history(self, channel_id: str) -> List[Dict]:
        """Extract conversation history of a channel, [without thread content]"""
        try:
            response = self.__client.conversations_history(channel=channel_id)
            messages = response["messages"]
            return messages
        except SlackApiError as e:
            print(f"Error fetching conversation history: {e.response['error']}")
            traceback.print_exc()

    def get_thread_messages(self, channel_id: str, ts: str) -> List[Dict]:
        """Extract thread messages"""
        try:
            response = self.__client.conversations_replies(channel=channel_id,ts=ts)
            messages_thread = response["messages"]
            return messages_thread
        except SlackApiError as e:
            print(f"Error fetching conversation thread messages: {e.response['error']}")
            traceback.print_exc()

# %%
bot_token = 'xoxb-'
slackExtr = SlackDataExtractor(bot_token=bot_token)

# %%
slackExtr.get_channels(name_only=True)
# Out:
# [{'id': 'C05QD1EPG3H', 'name': 'slack-python-integration'},
#  {'id': 'C05QLTRE43Y', 'name': 'general'},
#  {'id': 'C05QTF1QR35', 'name': 'test-one-channel'},
#  {'id': 'C05QW0UA1HS', 'name': 'random'}]

# %%
slackExtr.get_channel_history(channel_id='C05QD1EPG3H')
# Out:
# [{'client_msg_id': '08c3d3f0-da20-40c4-9b48-426c5d1c2112',
#   'type': 'message',
#   'text': 'i just cecked',
#   'user': 'U05TTFYS469',
#   'ts': '1695726883.099609',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'it4qI',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'i just cecked'}]}]}],
#   'team': 'T05QTH8Q2TU'},
#  {'client_msg_id': '5e3a615f-e813-4d74-834a-6a1da795409f',
#   'type': 'message',
#   'text': 'it works when i actively live on here',
#   'user': 'U05TTFYS469',
#   'ts': '1695726866.228409',
#   'blocks': [{'type': 'rich_text',
#     'block_id': '9D4/',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text',
#         'text': 'it works when i actively live on here'}]}]}],
#   'team': 'T05QTH8Q2TU'},
#  {'client_msg_id': 'bab9b0cc-9826-47d2-b12c-55147b606966',
#   'type': 'message',
#   'text': 'may be turining off all the notifications might work',
#   'user': 'U05S9QZ2BR9',
#   'ts': '1695726805.858049',
#   'blocks': [{'type': 'rich_text',
#     'block_id': '6AG',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text',
#         'text': 'may be turining off all the notifications might work'}]}]}],
#   'team': 'T05QTH8Q2TU'},
#  {'client_msg_id': 'b7461366-537c-4d9d-acc2-83a29535ab63',
#   'type': 'message',
#   'text': 'pop ups come as notifying',
#   'user': 'U05TTFYS469',
#   'ts': '1695726781.626679',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'lS=HJ',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'pop ups come as notifying'}]}]}],
#   'team': 'T05QTH8Q2TU'},
#  {'client_msg_id': '1ece6933-3b6a-4db9-a4bf-046ab0d814fa',
#   'type': 'message',
#   'text': 'it still works',
#   'user': 'U05TTFYS469',
#   'ts': '1695726766.674689',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'GSv',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'it still works'}]}]}],
#   'team': 'T05QTH8Q2TU'},
#  {'client_msg_id': '6bd6cdb4-d529-4383-a067-d4589a10025f',
#   'type': 'message',
#   'text': 'yeah',
#   'user': 'U05TTFYS469',
#   'ts': '1695726761.281489',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'hfuy',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'yeah'}]}]}],
#   'team': 'T05QTH8Q2TU'},
#  {'client_msg_id': '994394d9-c1a9-4210-a0eb-d1ea30cea102',
#   'type': 'message',
#   'text': 'send something',
#   'user': 'U05TTFYS469',
#   'ts': '1695726741.272319',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'V5al',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'send something'}]}]}],
#   'team': 'T05QTH8Q2TU'},
#  {'client_msg_id': '87211afc-760c-422a-98b5-7af8a07372dc',
#   'type': 'message',
#   'text': 'but still comes pop ups at bottom right corner',
#   'user': 'U05TTFYS469',
#   'ts': '1695726728.569319',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'Ps0',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text',
#         'text': 'but still comes pop ups at bottom right corner'}]}]}],
#   'team': 'T05QTH8Q2TU',
#   'thread_ts': '1695726728.569319',
#   'reply_count': 1,
#   'reply_users_count': 1,
#   'latest_reply': '1695726750.572029',
#   'reply_users': ['U05S9QZ2BR9'],
#   'is_locked': False,
#   'subscribed': False},
#  {'client_msg_id': '78f02529-1c41-4b9e-a917-9624799e18ae',
#   'type': 'message',
#   'text': ':zany_face:',
#   'user': 'U05TTFYS469',
#   'ts': '1695726705.979569',
#   'blocks': [{'type': 'rich_text',
#     'block_id': '=JEo6',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'emoji',
#         'name': 'zany_face',
#         'unicode': '1f92a'}]}]}],
#   'team': 'T05QTH8Q2TU'},
#  {'client_msg_id': '2244bd84-19a3-4210-94bc-3a952cf1dc90',
#   'type': 'message',
#   'text': 'done',
#   'user': 'U05TTFYS469',
#   'ts': '1695726689.940019',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'PHTEd',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'done'}]}]}],
#   'team': 'T05QTH8Q2TU',
#   'reactions': [{'name': 'raised_hands',
#     'users': ['U05S9QZ2BR9'],
#     'count': 1}]},
#  {'client_msg_id': 'd08e9562-3a63-4319-b81e-354e22ebc4a0',
#   'type': 'message',
#   'text': 'yes this channel',
#   'user': 'U05S9QZ2BR9',
#   'ts': '1695726673.299299',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'pFd',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'yes this channel'}]}]}],
#   'team': 'T05QTH8Q2TU'},
#  {'client_msg_id': 'a82b1bc3-6782-4336-af29-ef9e39f29a4b',
#   'type': 'message',
#   'text': 'only this channel?',
#   'user': 'U05TTFYS469',
#   'ts': '1695726666.298859',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'eEI',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'only this channel?'}]}]}],
#   'team': 'T05QTH8Q2TU'},
#  {'client_msg_id': 'fa1894c0-e133-488c-aa5c-6cc954dca3a8',
#   'type': 'message',
#   'text': 'got it',
#   'user': 'U05TTFYS469',
#   'ts': '1695726651.845439',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'Wrp',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'got it'}]}]}],
#   'team': 'T05QTH8Q2TU'},
#  {'client_msg_id': '05789b6a-48f0-42be-b192-ca54ad326019',
#   'type': 'message',
#   'text': "I'm new to here",
#   'user': 'U05TTFYS469',
#   'ts': '1695726632.669819',
#   'blocks': [{'type': 'rich_text',
#     'block_id': '+Wy',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': "I'm new to here"}]}]}],
#   'team': 'T05QTH8Q2TU',
#   'thread_ts': '1695726632.669819',
#   'reply_count': 1,
#   'reply_users_count': 1,
#   'latest_reply': '1695726691.136589',
#   'reply_users': ['U05S9QZ2BR9'],
#   'is_locked': False,
#   'subscribed': False},
#  {'client_msg_id': '1213a16a-cd93-40e5-9866-ffc949e4c7c1',
#   'type': 'message',
#   'text': 'how to mute',
#   'user': 'U05TTFYS469',
#   'ts': '1695726603.208809',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'zGhxe',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'how to mute'}]}]}],
#   'team': 'T05QTH8Q2TU',
#   'thread_ts': '1695726603.208809',
#   'reply_count': 3,
#   'reply_users_count': 1,
#   'latest_reply': '1695726653.238749',
#   'reply_users': ['U05S9QZ2BR9'],
#   'is_locked': False,
#   'subscribed': False},
#  {'client_msg_id': '4d3991ff-db93-4525-acf5-d8d21e74c10e',
#   'type': 'message',
#   'text': 'Mute the channel',
#   'user': 'U05S9QZ2BR9',
#   'ts': '1695726572.648239',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'HSQF0',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'Mute the channel'}]}]}],
#   'team': 'T05QTH8Q2TU'},
#  {'client_msg_id': '5db3b3da-7d7b-41f8-ab4e-aa51d14c2848',
#   'type': 'message',
#   'text': "I'm also enogh up to now",
#   'user': 'U05TTFYS469',
#   'ts': '1695726559.871789',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'ri=x',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': "I'm also enogh up to now"}]}]}],
#   'team': 'T05QTH8Q2TU',
#   'reactions': [{'name': 'eyes', 'users': ['U05S9QZ2BR9'], 'count': 1}]},
#  {'client_msg_id': '297399f3-f9f2-42a5-948d-83cc8aab71c7',
#   'type': 'message',
#   'text': 'ok good',
#   'user': 'U05TTFYS469',
#   'ts': '1695726548.903149',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'vmyH',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'ok good'}]}]}],
#   'team': 'T05QTH8Q2TU',
#   'reactions': [{'name': 'smiling_face_with_3_hearts',
#     'users': ['U05S9QZ2BR9'],
#     'count': 1}]},
#  {'client_msg_id': '6e98cee6-2d0f-4ffa-bf17-e01662f46949',
#   'type': 'message',
#   'text': '<@U05QQKKAJNR> :dolls:',
#   'user': 'U05TTFYS469',
#   'ts': '1695726535.177089',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'OJnX',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'user', 'user_id': 'U05QQKKAJNR'},
#        {'type': 'text', 'text': ' '},
#        {'type': 'emoji', 'name': 'dolls', 'unicode': '1f38e'}]}]}],
#   'team': 'T05QTH8Q2TU'},
#  {'client_msg_id': 'e2a4fb74-bd17-42fc-9457-e7279fd8ed21',
#   'type': 'message',
#   'text': "This will be enough for now. Did some tests and it's done",
#   'user': 'U05S9QZ2BR9',
#   'ts': '1695726509.925809',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'I/R',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text',
#         'text': "This will be enough for now. Did some tests and it's done"}]}]}],
#   'team': 'T05QTH8Q2TU'},
#  {'client_msg_id': 'af30cc92-de0c-4a25-ae7b-ab16567d712a',
#   'type': 'message',
#   'text': ':grin::grin:',
#   'user': 'U05S9QZ2BR9',
#   'ts': '1695726468.781839',
#   'blocks': [{'type': 'rich_text',
#     'block_id': '+BOI=',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'emoji', 'name': 'grin', 'unicode': '1f601'},
#        {'type': 'emoji', 'name': 'grin', 'unicode': '1f601'}]}]}],
#   'team': 'T05QTH8Q2TU'},
#  {'client_msg_id': '1c5a15bd-1f25-4e9e-99bc-e50c0636828d',
#   'type': 'message',
#   'text': ':firecracker:',
#   'user': 'U05TTFYS469',
#   'ts': '1695726458.139259',
#   'blocks': [{'type': 'rich_text',
#     'block_id': '=hc',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'emoji',
#         'name': 'firecracker',
#         'unicode': '1f9e8'}]}]}],
#   'team': 'T05QTH8Q2TU'},
#  {'client_msg_id': '780db0f5-f07a-489b-9ace-b7078da64a65',
#   'type': 'message',
#   'text': 'Boooooom',
#   'user': 'U05TTFYS469',
#   'ts': '1695726436.761459',
#   'blocks': [{'type': 'rich_text',
#     'block_id': '4=B2J',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'Boooooom'}]}]}],
#   'team': 'T05QTH8Q2TU'},
#  {'client_msg_id': 'b0a99e88-ea29-4e30-b348-965339015577',
#   'type': 'message',
#   'text': ':smiling_face_with_tear:',
#   'user': 'U05TTFYS469',
#   'ts': '1695702012.998449',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'JT0p5',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'emoji',
#         'name': 'smiling_face_with_tear',
#         'unicode': '1f972'}]}]}],
#   'team': 'T05QTH8Q2TU',
#   'reactions': [{'name': 'eyes', 'users': ['U05S9QZ2BR9'], 'count': 1}]},
#  {'client_msg_id': 'bfbc1dc0-6780-4d93-af16-14cb13884aff',
#   'type': 'message',
#   'text': "It's cold here today:wink:",
#   'user': 'U05QQKKAJNR',
#   'ts': '1695701947.561829',
#   'blocks': [{'type': 'rich_text',
#     'block_id': '7/TQQ',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': "It's cold here today"},
#        {'type': 'emoji', 'name': 'wink', 'unicode': '1f609'}]}]}],
#   'team': 'T05QTH8Q2TU',
#   'thread_ts': '1695701947.561829',
#   'reply_count': 2,
#   'reply_users_count': 1,
#   'latest_reply': '1695701987.202169',
#   'reply_users': ['U05S9QZ2BR9'],
#   'is_locked': False,
#   'subscribed': False,
#   'reactions': [{'name': 'eyes',
#     'users': ['U05TTFYS469', 'U05QQKKAJNR'],
#     'count': 2}]},
#  {'client_msg_id': 'b52ae6e9-96e0-494f-8d9c-c097d02621f2',
#   'type': 'message',
#   'text': '<@U05S9QZ2BR9> rrr :grin:',
#   'user': 'U05TTFYS469',
#   'ts': '1695701914.605159',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'O4gW',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'user', 'user_id': 'U05S9QZ2BR9'},
#        {'type': 'text', 'text': ' rrr '},
#        {'type': 'emoji', 'name': 'grin', 'unicode': '1f601'}]}]}],
#   'team': 'T05QTH8Q2TU'},
#  {'client_msg_id': '3a562715-25b5-42f9-aece-f9788909c5ab',
#   'type': 'message',
#   'text': 'yoyo:stuck_out_tongue_winking_eye:',
#   'user': 'U05TTFYS469',
#   'ts': '1695701884.598349',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'Arj',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'yoyo'},
#        {'type': 'emoji',
#         'name': 'stuck_out_tongue_winking_eye',
#         'unicode': '1f61c'}]}]}],
#   'team': 'T05QTH8Q2TU'},
#  {'client_msg_id': '04c2eb3b-4bb4-4848-b0fe-f0de5b6b42a9',
#   'type': 'message',
#   'text': ':smiling_face_with_3_hearts:',
#   'user': 'U05TTFYS469',
#   'ts': '1695701869.669139',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'NP1',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'emoji',
#         'name': 'smiling_face_with_3_hearts',
#         'unicode': '1f970'}]}]}],
#   'team': 'T05QTH8Q2TU',
#   'thread_ts': '1695701869.669139',
#   'reply_count': 2,
#   'reply_users_count': 2,
#   'latest_reply': '1695709231.618649',
#   'reply_users': ['U05S9QZ2BR9', 'U05QQKKAJNR'],
#   'is_locked': False,
#   'subscribed': False},
#  {'client_msg_id': 'ca372909-21b5-4d9c-a4c6-ec36eead3159',
#   'type': 'message',
#   'text': ':melting_face:',
#   'user': 'U05S9QZ2BR9',
#   'ts': '1695701865.048749',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'Dcb',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'emoji',
#         'name': 'melting_face',
#         'unicode': '1fae0'}]}]}],
#   'team': 'T05QTH8Q2TU'},
#  {'type': 'message',
#   'subtype': 'channel_join',
#   'ts': '1695701700.018619',
#   'user': 'U05S9QZ2BR9',
#   'text': '<@U05S9QZ2BR9> has joined the channel'},
#  {'client_msg_id': '9bcfd426-6659-4a72-9a6b-13faeb955b60',
#   'type': 'message',
#   'text': 'Hbu',
#   'user': 'U05TTFYS469',
#   'ts': '1695700644.025159',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'Yv=t',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'Hbu'}]}]}],
#   'team': 'T05QTH8Q2TU'},
#  {'client_msg_id': '6a3ed815-c8e3-4ca6-9e67-7de74c169d8a',
#   'type': 'message',
#   'text': "I'm fine",
#   'user': 'U05TTFYS469',
#   'ts': '1695700637.419289',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'Bxau',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': "I'm fine"}]}]}],
#   'team': 'T05QTH8Q2TU',
#   'thread_ts': '1695700637.419289',
#   'reply_count': 1,
#   'reply_users_count': 1,
#   'latest_reply': '1695701831.489679',
#   'reply_users': ['U05S9QZ2BR9'],
#   'is_locked': False,
#   'subscribed': False},
#  {'client_msg_id': '1fdb98ed-c79b-4d0c-958b-ba68df9b6f55',
#   'type': 'message',
#   'text': 'Hi',
#   'user': 'U05TTFYS469',
#   'ts': '1695700632.011449',
#   'blocks': [{'type': 'rich_text',
#     'block_id': '0bl',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'Hi'}]}]}],
#   'team': 'T05QTH8Q2TU'},
#  {'client_msg_id': '299fbf61-c5a7-40c5-8cbb-ee96a1c5f436',
#   'type': 'message',
#   'text': 'Hellow <@U05TTFYS469> how are you',
#   'user': 'U05QQKKAJNR',
#   'ts': '1695700619.473279',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'm35m',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'Hellow '},
#        {'type': 'user', 'user_id': 'U05TTFYS469'},
#        {'type': 'text', 'text': ' how are you'}]}]}],
#   'team': 'T05QTH8Q2TU'},
#  {'type': 'message',
#   'subtype': 'channel_join',
#   'ts': '1695700418.806359',
#   'user': 'U05TTFYS469',
#   'text': '<@U05TTFYS469> has joined the channel'},
#  {'type': 'message',
#   'subtype': 'channel_join',
#   'ts': '1694768535.575329',
#   'user': 'U05SEBBE3FF',
#   'text': '<@U05SEBBE3FF> has joined the channel',
#   'inviter': 'U05QQKKAJNR'},
#  {'type': 'message',
#   'subtype': 'channel_join',
#   'ts': '1694701615.504869',
#   'user': 'U05SA0WQURG',
#   'text': '<@U05SA0WQURG> has joined the channel',
#   'inviter': 'U05QQKKAJNR'},
#  {'type': 'message',
#   'subtype': 'bot_add',
#   'text': 'added an integration to this channel: <https://testslackpython-group.slack.com/services/B05T1KPTSGG|Get Messages>',
#   'user': 'U05QQKKAJNR',
#   'bot_id': 'B05T1KPTSGG',
#   'bot_link': '<https://testslackpython-group.slack.com/services/B05T1KPTSGG|Get Messages>',
#   'ts': '1694700897.117339'},
#  {'client_msg_id': '8a51137c-ae97-4c6e-8f34-9d382b9d7a13',
#   'type': 'message',
#   'text': 'new messages',
#   'user': 'U05QQKKAJNR',
#   'ts': '1694673617.441099',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'UtXc',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'new messages'}]}]}],
#   'team': 'T05QTH8Q2TU'},
#  {'type': 'message',
#   'subtype': 'bot_add',
#   'text': 'added an integration to this channel: <https://testslackpython-group.slack.com/services/B05SP0QNM3K|Get Messages>',
#   'user': 'U05QQKKAJNR',
#   'bot_id': 'B05SP0QNM3K',
#   'bot_link': '<https://testslackpython-group.slack.com/services/B05SP0QNM3K|Get Messages>',
#   'ts': '1694673316.522049'},
#  {'type': 'message',
#   'subtype': 'bot_message',
#   'text': ' Hellow This is a WebHook Triggered Message!',
#   'ts': '1694573657.563109',
#   'bot_id': 'B05QRTSS2BF',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'wI3',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text',
#         'text': 'Hellow This is a WebHook Triggered Message!'}]}]}]},
#  {'type': 'message',
#   'subtype': 'bot_message',
#   'text': ' Hellow This is a WebHook Triggered Message!',
#   'ts': '1694485116.228589',
#   'bot_id': 'B05QRTSS2BF',
#   'blocks': [{'type': 'rich_text',
#     'block_id': '7F2',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text',
#         'text': 'Hellow This is a WebHook Triggered Message!'}]}]}]},
#  {'type': 'message',
#   'subtype': 'bot_add',
#   'text': 'added an integration to this channel: <https://testslackpython-group.slack.com/services/B05RJFTR0H4|Test Bot>',
#   'user': 'U05QQKKAJNR',
#   'bot_id': 'B05RJFTR0H4',
#   'bot_link': '<https://testslackpython-group.slack.com/services/B05RJFTR0H4|Test Bot>',
#   'ts': '1694411198.996519'},
#  {'type': 'message',
#   'subtype': 'bot_add',
#   'text': 'added an integration to this channel: <https://testslackpython-group.slack.com/services/B05RTHQS10U|Test Bot>',
#   'user': 'U05QQKKAJNR',
#   'bot_id': 'B05RTHQS10U',
#   'bot_link': '<https://testslackpython-group.slack.com/services/B05RTHQS10U|Test Bot>',
#   'ts': '1694410763.992579'},
#  {'client_msg_id': '1a8e0d0c-340f-4aa4-bad4-04d3987e5714',
#   'type': 'message',
#   'text': 'test message',
#   'user': 'U05QQKKAJNR',
#   'ts': '1694400010.001569',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'lkJF2',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'test message'}]}]}],
#   'team': 'T05QTH8Q2TU'},
#  {'type': 'message',
#   'subtype': 'bot_message',
#   'text': ' Hellow This is a WebHook Triggered Message!',
#   'ts': '1694399981.469559',
#   'bot_id': 'B05QRTSS2BF',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'YytG',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text',
#         'text': 'Hellow This is a WebHook Triggered Message!'}]}]}]},
#  {'client_msg_id': '62a55e27-fcac-47d0-84ee-a889cc21e1a6',
#   'type': 'message',
#   'text': 'Good morning',
#   'user': 'U05QQKKAJNR',
#   'ts': '1694395689.771739',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'zHErM',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'Good morning'}]}]}],
#   'team': 'T05QTH8Q2TU'},
#  {'client_msg_id': '8547901a-a624-4f35-9d0e-1c2ca3745b91',
#   'type': 'message',
#   'text': ':wave: Hello, Everyone!',
#   'user': 'U05QQKKAJNR',
#   'ts': '1694155421.735479',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'NfUp',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'emoji', 'name': 'wave', 'unicode': '1f44b'},
#        {'type': 'text', 'text': ' Hello, Everyone!'}]}]}],
#   'team': 'T05QTH8Q2TU'},
#  {'type': 'message',
#   'subtype': 'bot_add',
#   'text': 'added an integration to this channel: <https://testslackpython-group.slack.com/services/B05S0UZ3QQY|Test Bot>',
#   'user': 'U05QQKKAJNR',
#   'bot_id': 'B05S0UZ3QQY',
#   'bot_link': '<https://testslackpython-group.slack.com/services/B05S0UZ3QQY|Test Bot>',
#   'ts': '1694087212.057999'},
#  {'type': 'message',
#   'subtype': 'bot_message',
#   'text': ' Hellow World!',
#   'ts': '1693826789.077469',
#   'bot_id': 'B05QRTSS2BF',
#   'blocks': [{'type': 'rich_text',
#     'block_id': '+Gu',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'Hellow World!'}]}]}]},
#  {'type': 'message',
#   'subtype': 'bot_message',
#   'text': ' Hellow World!',
#   'ts': '1693826691.222709',
#   'bot_id': 'B05QRTSS2BF',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'j6RX',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'Hellow World!'}]}]}]},
#  {'type': 'message',
#   'subtype': 'bot_add',
#   'text': 'added an integration to this channel: <https://testslackpython-group.slack.com/services/B05QRTSS2BF|Test Bot>',
#   'user': 'U05QQKKAJNR',
#   'bot_id': 'B05QRTSS2BF',
#   'bot_link': '<https://testslackpython-group.slack.com/services/B05QRTSS2BF|Test Bot>',
#   'ts': '1693825391.847829'},
#  {'type': 'message',
#   'subtype': 'channel_join',
#   'ts': '1693811656.981149',
#   'user': 'U05QD2XCWQP',
#   'text': '<@U05QD2XCWQP> has joined the channel',
#   'inviter': 'U05QQKKAJNR'},
#  {'type': 'message',
#   'subtype': 'bot_add',
#   'text': 'added an integration to this channel: <https://testslackpython-group.slack.com/services/B05QLVB55V4|MyApp>',
#   'user': 'U05QQKKAJNR',
#   'bot_id': 'B05QLVB55V4',
#   'bot_link': '<https://testslackpython-group.slack.com/services/B05QLVB55V4|MyApp>',
#   'ts': '1693809053.553889'},
#  {'type': 'message',
#   'subtype': 'channel_join',
#   'ts': '1693808166.488619',
#   'user': 'U05QQKKAJNR',
#   'text': '<@U05QQKKAJNR> has joined the channel'}]

# %% [markdown]
# To illustrated the thread message extraction for following message, \
#
# ```json
# {'client_msg_id': '1213a16a-cd93-40e5-9866-ffc949e4c7c1',
#   'type': 'message',
#   'text': 'how to mute',
#   'user': 'U05TTFYS469',
#   'ts': '1695726603.208809', <- timestamp use in following function
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'zGhxe',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'how to mute'}]}]}],
#   'team': 'T05QTH8Q2TU',
#   'thread_ts': '1695726603.208809',
#   'reply_count': 3,
#   'reply_users_count': 1,
#   'latest_reply': '1695726653.238749',
#   'reply_users': ['U05S9QZ2BR9'],
#   'is_locked': False,
#   'subscribed': False}
# ```
# message with 3 replies under conversation id : C05QD1EPG3H

# %%
slackExtr.get_thread_messages(channel_id='C05QD1EPG3H', ts='1695726603.208809')
# Out:
# [{'client_msg_id': '1213a16a-cd93-40e5-9866-ffc949e4c7c1',
#   'type': 'message',
#   'text': 'how to mute',
#   'user': 'U05TTFYS469',
#   'ts': '1695726603.208809',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'zGhxe',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'how to mute'}]}]}],
#   'team': 'T05QTH8Q2TU',
#   'thread_ts': '1695726603.208809',
#   'reply_count': 3,
#   'reply_users_count': 1,
#   'latest_reply': '1695726653.238749',
#   'reply_users': ['U05S9QZ2BR9'],
#   'is_locked': False,
#   'subscribed': False},
#  {'client_msg_id': '2e51e5f2-ca1a-4558-bf3f-9dbd5bd5cd8e',
#   'type': 'message',
#   'text': 'oh wait',
#   'user': 'U05S9QZ2BR9',
#   'ts': '1695726614.525739',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'OaHGI',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text', 'text': 'oh wait'}]}]}],
#   'team': 'T05QTH8Q2TU',
#   'thread_ts': '1695726603.208809',
#   'parent_user_id': 'U05TTFYS469'},
#  {'client_msg_id': 'a40eca8f-1206-42d6-92c1-9fbfb029dffe',
#   'type': 'message',
#   'text': 'You gotta click the channel name',
#   'user': 'U05S9QZ2BR9',
#   'ts': '1695726632.378189',
#   'blocks': [{'type': 'rich_text',
#     'block_id': 'sEotA',
#     'elements': [{'type': 'rich_text_section',
#       'elements': [{'type': 'text',
#         'text': 'You gotta click the channel name'}]}]}],
#   'team': 'T05QTH8Q2TU',
#   'thread_ts': '1695726603.208809',
#   'parent_user_id': 'U05TTFYS469'},
#  {'type': 'message',
#   'text': '',
#   'files': [{'id': 'F05THLRTET1',
#     'created': 1695726648,
#     'timestamp': 1695726648,
#     'name': 'image.png',
#     'title': 'image.png',
#     'mimetype': 'image/png',
#     'filetype': 'png',
#     'pretty_type': 'PNG',
#     'user': 'U05S9QZ2BR9',
#     'user_team': 'T05QTH8Q2TU',
#     'editable': False,
#     'size': 55406,
#     'mode': 'hosted',
#     'is_external': False,
#     'external_type': '',
#     'is_public': True,
#     'public_url_shared': False,
#     'display_as_bot': False,
#     'username': '',
#     'url_private': 'https://files.slack.com/files-pri/T05QTH8Q2TU-F05THLRTET1/image.png',
#     'url_private_download': 'https://files.slack.com/files-pri/T05QTH8Q2TU-F05THLRTET1/download/image.png',
#     'media_display_type': 'unknown',
#     'thumb_64': 'https://files.slack.com/files-tmb/T05QTH8Q2TU-F05THLRTET1-ee990c2cb9/image_64.png',
#     'thumb_80': 'https://files.slack.com/files-tmb/T05QTH8Q2TU-F05THLRTET1-ee990c2cb9/image_80.png',
#     'thumb_360': 'https://files.slack.com/files-tmb/T05QTH8Q2TU-F05THLRTET1-ee990c2cb9/image_360.png',
#     'thumb_360_w': 360,
#     'thumb_360_h': 313,
#     'thumb_480': 'https://files.slack.com/files-tmb/T05QTH8Q2TU-F05THLRTET1-ee990c2cb9/image_480.png',
#     'thumb_480_w': 480,
#     'thumb_480_h': 417,
#     'thumb_160': 'https://files.slack.com/files-tmb/T05QTH8Q2TU-F05THLRTET1-ee990c2cb9/image_160.png',
#     'original_w': 604,
#     'original_h': 525,
#     'thumb_tiny': 'AwApADCkpAHKg/jTvlx91f8Avqm9vpS49v1FAC/L/dX/AL6NNIy3GB+NHHvSUAKVx3H502iigBw7807J7U0d6dtFACfMPWkyfWl2+4pCCKAE2n0NGCOoxQTmkoAWnZH94000lADuPU/lSUlFABRRRQB//9k=',
#     'permalink': 'https://testslackpython-group.slack.com/files/U05S9QZ2BR9/F05THLRTET1/image.png',
#     'permalink_public': 'https://slack-files.com/T05QTH8Q2TU-F05THLRTET1-b87e19a640',
#     'is_starred': False,
#     'has_rich_preview': False,
#     'file_access': 'visible'}],
#   'upload': False,
#   'user': 'U05S9QZ2BR9',
#   'display_as_bot': False,
#   'ts': '1695726653.238749',
#   'client_msg_id': '57b4fd2b-27af-4e52-a323-d1e71dd45344',
#   'thread_ts': '1695726603.208809',
#   'parent_user_id': 'U05TTFYS469'}]
