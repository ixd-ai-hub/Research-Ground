# %% [markdown]
# <a href="https://colab.research.google.com/github/ixd-ai-hub/Research-Ground/blob/feature%2FCU-865d7mpad-sticker-generation-models/models/discoart_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install discoart
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 73 kB 1.3 MB/s
# ...
#      |████████████████████████████████| 53 kB 2.6 MB/s
# ...
#      |████████████████████████████████| 53 kB 1.7 MB/s
# ...
#      |████████████████████████████████| 641 kB 8.7 MB/s
# ...
#      |████████████████████████████████| 1.4 MB 37.8 MB/s
# ...
#      |████████████████████████████████| 2.5 MB 37.4 MB/s
# ...
#      |████████████████████████████████| 230 kB 42.7 MB/s
# ...
#      |████████████████████████████████| 1.4 MB 48.8 MB/s
# ...
#      |████████████████████████████████| 1.8 MB 42.2 MB/s
# ...
#      |████████████████████████████████| 235 kB 57.9 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 56.8 MB/s
# ...
#      |████████████████████████████████| 55 kB 3.2 MB/s
# ...
#      |████████████████████████████████| 57 kB 5.0 MB/s
# ...
#      |████████████████████████████████| 3.8 MB 33.9 MB/s
# ...
#      |████████████████████████████████| 4.0 MB 38.5 MB/s
# ...

# %%
from discoart import show_config, create

show_config('discoart-id')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-3-5d7581d6eab3> in <module>
#       1 from discoart import show_config, create
#       2
# ----> 3 show_config('discoart-id')
#
# /usr/local/lib/python3.7/dist-packages/discoart/config.py in show_config(docs, only_non_default)
#      85     only_non_default: bool = True,
#      86 ):
# ---> 87     cfg = _extract_config_from_docs(docs)
#      88     print_args_table(cfg, only_non_default=only_non_default)
#      89
#
# /usr/local/lib/python3.7/dist-packages/discoart/config.py in _extract_config_from_docs(docs)
#     220         cfg = vars(docs)
#     221     elif isinstance(docs, str):
# --> 222         cfg = DocumentArray.pull(docs)[0].tags
#     223
#     224     return load_config(cfg)
#
# ...

# %%
da = create(
    text_prompts='A painting of sea cliffs in a tumultuous storm, Trending on ArtStation.',
    # init_image='https://d2vyhzeko0lke5.cloudfront.net/2f4f6dfa5a05e078469ebe57e77b72f0.png',
    skip_steps=100,
)
# Out:
# 2022-09-11 07:12:26,392 - discoart - INFO -
# W&B dashboard is disabled. To enable the online dashboard for tracking losses, gradients,
# scheduling tracking, please set `WANDB_MODE=online` before running/importing DiscoArt. e.g.
#
#     import os
#     os.environ['WANDB_MODE'] = 'online'
#
#     from discoart import create
#     create(...)
#
# 2022-09-11 07:12:26,395 - discoart - INFO - creating artworks `discoart-860d325631a011ed9f100242ac1c0002` (0/4)...
# IntProgress(value=1, bar_style='info', description='Baking 1/4: ', max=4)
# ...
# ERROR:wandb.jupyter:Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
#   0%|          | 0/150 [00:00<?, ?it/s]
